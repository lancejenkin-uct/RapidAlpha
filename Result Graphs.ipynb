# %%
from BaseDelegate import BaseDelegate
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
bd = BaseDelegate()

# %%
measurement_file = "../testdata/report/reflective/120903/1.db"
alpha = bd.loadAbsorptionCoefficient(measurement_file)

# %%
t = arange(0, len(alpha.power_cepstrum) / (44100.0 / 7.0),  1 / (44100.0 / 7.0))
plot(1000 * t, alpha.power_cepstrum, ls="--")
plot(1000 * t, alpha.microphone_cepstrum, color="black", ls="-")
xlim(0, 15)
ylim(-0.5, 1)
grid(True)
xlabel("Quefrency (ms)")
ylabel("Amplitude")

ax = gca()
axins = i(ax, 0.75, loc=1) # zoom = 6
axins.plot(1000 * t[25:40], alpha.power_cepstrum[25:40], ls="--")
axins.plot(1000 * t[25:40], alpha.microphone_cepstrum[25:40], color="black", ls="-")

grid(True)
